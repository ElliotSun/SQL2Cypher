# %%
#Imports
import collections
import re

from conf.config import Config
from pathlib import Path
import json
import pandas as pd
from mo_sql_parsing import parse
from utils.SQLParser import SQLParser

# %% [markdown]
# 1. Parse train_spider.json to dict

# %%
json_path = Path(Config.spider_folder +'/train_spider.json')
spider_queries_df = pd.read_json(json_path)
spider_queries_df = spider_queries_df.drop(columns =['sql'])
spider_queries_df
# Out:
#                       db_id  \
# 0     department_management
# 1     department_management
# 2     department_management
# 3     department_management
# 4     department_management
# ...                     ...
# 6995        culture_company
# 6996        culture_company
# 6997        culture_company
# 6998        culture_company
# 6999        culture_company
#
#                                                   query  \
# 0            SELECT count(*) FROM head WHERE age  >  56
# 1     SELECT name ,  born_state ,  age FROM head ORD...
# 2     SELECT creation ,  name ,  budget_in_billions ...
# 3     SELECT max(budget_in_billions) ,  min(budget_i...
# 4     SELECT avg(num_employees) FROM department WHER...
# ...                                                 ...
# 6995  SELECT T1.company_name FROM culture_company AS...
# 6996  SELECT T1.title ,  T3.book_title FROM movie AS...
# 6997  SELECT T1.title ,  T3.book_title FROM movie AS...
# 6998  SELECT T2.company_name FROM movie AS T1 JOIN c...
# 6999  SELECT T2.company_name FROM movie AS T1 JOIN c...
#
#                                              query_toks  \
# 0     [SELECT, count, (, *, ), FROM, head, WHERE, ag...
# 1     [SELECT, name, ,, born_state, ,, age, FROM, he...
# 2     [SELECT, creation, ,, name, ,, budget_in_billi...
# 3     [SELECT, max, (, budget_in_billions, ), ,, min...
# 4     [SELECT, avg, (, num_employees, ), FROM, depar...
# ...                                                 ...
# 6995  [SELECT, T1.company_name, FROM, culture_compan...
# 6996  [SELECT, T1.title, ,, T3.book_title, FROM, mov...
# 6997  [SELECT, T1.title, ,, T3.book_title, FROM, mov...
# 6998  [SELECT, T2.company_name, FROM, movie, AS, T1,...
# 6999  [SELECT, T2.company_name, FROM, movie, AS, T1,...
#
#                                     query_toks_no_value  \
# 0     [select, count, (, *, ), from, head, where, ag...
# 1     [select, name, ,, born_state, ,, age, from, he...
# 2     [select, creation, ,, name, ,, budget_in_billi...
# 3     [select, max, (, budget_in_billions, ), ,, min...
# 4     [select, avg, (, num_employees, ), from, depar...
# ...                                                 ...
# 6995  [select, t1, ., company_name, from, culture_co...
# 6996  [select, t1, ., title, ,, t3, ., book_title, f...
# 6997  [select, t1, ., title, ,, t3, ., book_title, f...
# 6998  [select, t2, ., company_name, from, movie, as,...
# 6999  [select, t2, ., company_name, from, movie, as,...
#
#                                                question  \
# 0     How many heads of the departments are older th...
# 1     List the name, born state and age of the heads...
# 2     List the creation year, name and budget of eac...
# 3     What are the maximum and minimum budget of the...
# 4     What is the average number of employees of the...
# ...                                                 ...
# 6995  What are all the company names that have a boo...
# 6996  Show the movie titles and book titles for all ...
# 6997  What are the titles of movies and books corres...
# 6998  Show all company names with a movie directed i...
# 6999  What are all company names that have a corresp...
#
#                                           question_toks
# 0     [How, many, heads, of, the, departments, are, ...
# 1     [List, the, name, ,, born, state, and, age, of...
# 2     [List, the, creation, year, ,, name, and, budg...
# 3     [What, are, the, maximum, and, minimum, budget...
# 4     [What, is, the, average, number, of, employees...
# ...                                                 ...
# 6995  [What, are, all, the, company, names, that, ha...
# 6996  [Show, the, movie, titles, and, book, titles, ...
# 6997  [What, are, the, titles, of, movies, and, book...
# 6998  [Show, all, company, names, with, a, movie, di...
# 6999  [What, are, all, company, names, that, have, a...
#
# [7000 rows x 6 columns]

# %% [markdown]
# 2. Read the relationship json

# %%
relationship_path = Path(Config.spider_folder+'/consolidated_relations.json')
with open(relationship_path) as json_file:
    spider_relationship = json.load(json_file)

# %% [markdown]
# 3. Load table in use csv file if not all tables were loaded into neo4j

# %%
iter_csv = pd.read_csv(Config.spider_folder + '/table_in_use.csv', iterator=True, chunksize=1000)
db_in_use_df = pd.concat([chunk[chunk['Imported'] == 1] for chunk in iter_csv])
imported_dbs = db_in_use_df['db_id'].tolist()

# %%
#clean up dataframe. only keep rows with db_id in the imported list
spider_queries_df = spider_queries_df[spider_queries_df['db_id'].isin(imported_dbs)].sort_values(by=['db_id'])
spider_queries_df = spider_queries_df.reset_index(drop=True)

# %%
#parse sql query and reformat the result before conversion
def parse_sql(query: str, db_id: str):
    parsed_query = parse(query)
    #First get table alias map to be used for replace the alias in select and where clause
    table_alias_map = {} #alias as key, table name as value
    relationships = next(relationships['db_relationships'] for relationships in spider_relationship if relationships['db_id'] == db_id)
    if 'join' not in query.lower():
        return parsed_query
    for t in parsed_query['from']:
        if 'join' not in t:
            if t['name'] is None:
                continue
            else:
                table_alias_map[t['name']] = t['value']
        else:
            table_alias_map[t['join']['name']] = t['join']['value']
    if len(table_alias_map) == 0:
        return parsed_query
    #Replace mapping table name with actual table name
    for relationship in relationships:
        table_name = list(relationship.keys())[0]
        table_relation = relationship[table_name]
        if 'mapping' not in table_relation.keys() or table_relation['mapping'] is None:
            continue
        for key in table_alias_map.keys():
            if table_alias_map[key] == table_relation['mapping']:
                table_alias_map[key] = table_relation['to']
    #print(table_alias_map)
    #replace the alias with table name then parse sql again
    for key, value in table_alias_map.items():
        query = query.replace("{}.".format(str(key)), "{}.".format(value.lower()))
        query = query.replace(".{}".format(str(key)), ".{}".format(value))
    return parse(query)

def generate_cypher(query:str, db_id:str) -> str:
    try:
        cleaned_query = parse_sql(query,db_id)
        print(cleaned_query)
        sql_parser = SQLParser()
        sql_parser.generate_cypher(cleaned_query, query, db_id)
        cypher_query = sql_parser.get_cypher()
    except Exception as e:
        cypher_query = str(e)
    return cypher_query

def convert_to_cypher(sql_query: str, db_id: str):
    if 'UNION' not in sql_query.upper() and 'UNION ALL' not in sql_query.upper():
        cypher = generate_cypher(sql_query, db_id)
    else:
        split_key_work = ''
        cypher=''
        sub_queries = ''
        if 'UNION' in sql_query.upper():
            sub_queries = re.split("union", sql_query, flags=re.IGNORECASE)
            split_key_work = 'UNION '
        elif 'UNION ALL' in sql_query.upper():
            sub_queries = re.split("union all", sql_query, flags=re.IGNORECASE)
            split_key_work = 'UNION ALL '

        for subquery in sub_queries:
            print('sub query: '+ subquery)
            if cypher == '':
                cypher += generate_cypher(subquery, db_id)
            else:
                cypher = cypher.replace(';','')
                cypher += split_key_work + generate_cypher(subquery, db_id)
    return cypher

# %%
sql_query = "SELECT FacID FROM Faculty EXCEPT SELECT advisor FROM Student"
db_id = 'activity_1'
multistatement_keywords = ['UNION', 'UNION ALL', 'EXCEPT', 'INTERSECT']
if not [keyword for keyword in multistatement_keywords if(keyword in sql_query.upper())]:
    cypher = generate_cypher(sql_query, db_id)
else:
    if 'UNION' in sql_query.upper():
        split_key_work = ''
        cypher=''
        split_key_work = 'UNION ALL' if 'UNION ALL' in sql_query.upper() else 'UNION'
        sub_queries = re.split(split_key_work, sql_query, flags=re.IGNORECASE)
        for subquery in sub_queries:
            print('sub query: '+ subquery)
            if cypher == '':
                cypher += generate_cypher(subquery, db_id)
            else:
                cypher = cypher.replace(';','')
                cypher += split_key_work + generate_cypher(subquery, db_id)

cypher
# Out:
# {'select': {'value': 'FacID'}, 'from': 'Faculty'}
# ['n:Faculty']
# {'select': {'value': 'advisor'}, 'from': 'Student'}
# ['n:Student']
# 'MATCH (n:Faculty)  MATCH (n:Student)  RETURN  n.advisor  RETURN  n.FacID  ;'

# %%
#Uncomment below code for testing
#import random
#rand_row_number = random.randint(1, len(spider_queries_df))
#random_row = spider_queries_df.iloc[rand_row_number]
#random_row

# %%
spider_queries_df.columns.values.tolist()
# Out:
# ['db_id',
#  'query',
#  'query_toks',
#  'query_toks_no_value',
#  'question',
#  'question_toks']

# %%
Columns = collections.namedtuple('Columns',['Index','db_id','query','query_toks','query_toks_no_value','question','question_toks'])
spider_graph_df = spider_queries_df.copy()
valid_flags = []
for row in spider_graph_df.itertuples(index=True, name='Columns'):
    spider_graph_df.at[row.Index, 'query'] = convert_to_cypher(row.query, row.db_id)
    spider_graph_df.at[row.Index, 'query_toks'] = ''
    spider_graph_df.at[row.Index, 'query_toks_no_value'] = ''


spider_queries_df
# Out:
# {'select': [{'value': 'activity.activity_name'}, {'value': {'count': '*'}}], 'from': [{'value': 'Activity', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['activity.actID', 'faculty_participates_in.actID']}}], 'groupby': {'value': 'activity.actID'}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': [{'value': 'Fname'}, {'value': 'Lname'}, {'value': 'phone'}], 'from': 'Faculty', 'where': {'eq': ['Sex', {'literal': 'F'}]}}
# ['n:Faculty']
# {'select': [{'value': 'Fname'}, {'value': 'Lname'}, {'value': 'phone'}], 'from': 'Faculty', 'where': {'eq': ['Sex', {'literal': 'F'}]}}
# ['n:Faculty']
# {'select': [{'value': 'rank'}, {'value': 'Fname'}, {'value': 'Lname'}], 'from': 'Faculty'}
# ['n:Faculty']
# {'select': [{'value': 'rank'}, {'value': 'Fname'}, {'value': 'Lname'}], 'from': 'Faculty'}
# ['n:Faculty']
# {'select': {'value': {'distinct': {'value': 'building'}}}, 'from': 'Faculty'}
# ['n:Faculty']
# {'select': {'value': {'distinct': {'value': 'building'}}}, 'from': 'Faculty'}
# ['n:Faculty']
# {'select': {'value': {'distinct': {'value': 'rank'}}}, 'from': 'Faculty'}
# ['n:Faculty']
# {'select': {'value': {'distinct': {'value': 'rank'}}}, 'from': 'Faculty'}
# ['n:Faculty']
# {'select': {'value': {'count': '*'}}, 'from': 'Faculty'}
# ['n:Faculty']
# {'select': {'value': {'count': '*'}}, 'from': 'Faculty'}
# ['n:Faculty']
# {'select': {'value': 'faculty.FacID'}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'groupby': {'value': 'faculty.FacID'}, 'having': {'gte': [{'count': '*'}, 2]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': {'value': 'faculty.FacID'}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'groupby': {'value': 'faculty.FacID'}, 'having': {'gte': [{'count': '*'}, 2]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': {'value': 'FacID'}, 'from': 'Faculty', 'where': {'eq': ['Sex', {'literal': 'M'}]}}
# ['n:Faculty']
# {'select': {'value': 'activity_name'}, 'from': 'Activity'}
# ['n:Activity']
# {'select': {'value': {'count': '*'}}, 'from': 'Activity'}
# ['n:Activity']
# {'select': {'value': {'count': '*'}}, 'from': 'Activity'}
# ['n:Activity']
# {'select': {'value': {'count': {'distinct': {'value': 'FacID'}}}}, 'from': 'Faculty_participates_in'}
# ['n:Faculty_Participates_in']
# {'select': {'value': {'count': {'distinct': {'value': 'FacID'}}}}, 'from': 'Faculty_participates_in'}
# ['n:Faculty_Participates_in']
# {'select': {'value': {'count': '*'}}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}], 'where': {'and': [{'eq': ['faculty.fname', 'Mark']}, {'eq': ['faculty.lname', 'Giuliano']}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': {'count': '*'}}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}], 'where': {'and': [{'eq': ['faculty.fname', 'Mark']}, {'eq': ['faculty.lname', 'Giuliano']}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': 'activity.activity_name'}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}, {'join': {'name': 'T3', 'value': 'Activity'}, 'on': {'eq': ['activity.actid', 'faculty_participates_in.actid']}}], 'where': {'and': [{'eq': ['faculty.fname', 'Mark']}, {'eq': ['faculty.lname', 'Giuliano']}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': 'activity.activity_name'}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}, {'join': {'name': 'T3', 'value': 'Activity'}, 'on': {'eq': ['activity.actid', 'faculty_participates_in.actid']}}], 'where': {'and': [{'eq': ['faculty.fname', 'Mark']}, {'eq': ['faculty.lname', 'Giuliano']}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': [{'value': 'faculty.fname'}, {'value': 'faculty.lname'}, {'value': {'count': '*'}}, {'value': 'faculty.FacID'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}], 'groupby': {'value': 'faculty.FacID'}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': [{'value': 'faculty.fname'}, {'value': 'faculty.lname'}, {'value': {'count': '*'}}, {'value': 'faculty.FacID'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}], 'groupby': {'value': 'faculty.FacID'}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': 'activity_name'}, 'from': 'Activity'}
# ['n:Activity']
# {'select': [{'value': 'activity.activity_name'}, {'value': {'count': '*'}}], 'from': [{'value': 'Activity', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['activity.actID', 'faculty_participates_in.actID']}}], 'groupby': {'value': 'activity.actID'}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': 'FacID'}, 'from': 'Faculty', 'where': {'eq': ['Sex', {'literal': 'M'}]}}
# ['n:Faculty']
# {'select': {'value': {'count': '*'}}, 'from': 'Faculty', 'where': {'and': [{'eq': ['Sex', {'literal': 'F'}]}, {'eq': ['Rank', 'Professor']}]}}
# ['n:Faculty']
# {'select': [{'value': 'faculty.rank'}, {'value': {'count': '*'}}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'groupby': {'value': 'faculty.rank'}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'faculty.rank'}, {'value': {'count': '*'}}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'groupby': {'value': 'faculty.rank'}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'faculty.FacID'}, {'value': {'count': '*'}}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'groupby': {'value': 'faculty.FacID'}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'faculty.FacID'}, {'value': {'count': '*'}}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'groupby': {'value': 'faculty.FacID'}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'student.fname'}, {'value': 'student.lname'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'where': {'and': [{'eq': ['faculty.fname', 'Michael']}, {'eq': ['faculty.lname', 'Goodrich']}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'student.fname'}, {'value': 'student.lname'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'where': {'and': [{'eq': ['faculty.fname', 'Michael']}, {'eq': ['faculty.lname', 'Goodrich']}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': {'value': 'student.StuID'}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'where': {'eq': ['faculty.rank', 'Professor']}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': {'value': 'student.StuID'}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'where': {'eq': ['faculty.rank', 'Professor']}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'faculty.fname'}, {'value': 'faculty.lname'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'where': {'and': [{'eq': ['student.fname', 'Linda']}, {'eq': ['student.lname', 'Smith']}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'faculty.fname'}, {'value': 'faculty.lname'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'where': {'and': [{'eq': ['student.fname', 'Linda']}, {'eq': ['student.lname', 'Smith']}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'sex'}, {'value': {'count': '*'}}], 'from': 'Faculty', 'where': {'eq': ['rank', 'AsstProf']}, 'groupby': {'value': 'sex'}}
# ['n:Faculty']
# {'select': [{'value': 'sex'}, {'value': {'count': '*'}}], 'from': 'Faculty', 'where': {'eq': ['rank', 'AsstProf']}, 'groupby': {'value': 'sex'}}
# ['n:Faculty']
# {'select': {'value': 'rank'}, 'from': 'Faculty', 'groupby': {'value': 'rank'}, 'orderby': {'value': {'count': '*'}, 'sort': 'asc'}, 'limit': 1}
# ['n:Faculty']
# {'select': {'value': 'rank'}, 'from': 'Faculty', 'groupby': {'value': 'rank'}, 'orderby': {'value': {'count': '*'}, 'sort': 'asc'}, 'limit': 1}
# ['n:Faculty']
# {'select': {'value': {'count': '*'}}, 'from': 'Faculty', 'where': {'and': [{'eq': ['Sex', {'literal': 'F'}]}, {'eq': ['Rank', 'Professor']}]}}
# ['n:Faculty']
# {'select': [{'value': 'rank'}, {'value': 'sex'}, {'value': {'count': '*'}}], 'from': 'Faculty', 'groupby': [{'value': 'rank'}, {'value': 'sex'}]}
# ['n:Faculty']
# {'select': [{'value': 'rank'}, {'value': {'count': '*'}}], 'from': 'Faculty', 'groupby': {'value': 'rank'}}
# ['n:Faculty']
# {'select': [{'value': 'rank'}, {'value': {'count': '*'}}], 'from': 'Faculty', 'groupby': {'value': 'rank'}}
# ['n:Faculty']
# {'select': {'value': 'building'}, 'from': 'Faculty', 'where': {'eq': ['rank', 'Professor']}, 'groupby': {'value': 'building'}, 'having': {'gte': [{'count': '*'}, 10]}}
# ['n:Faculty']
# {'select': {'value': 'building'}, 'from': 'Faculty', 'where': {'eq': ['rank', 'Professor']}, 'groupby': {'value': 'building'}, 'having': {'gte': [{'count': '*'}, 10]}}
# ['n:Faculty']
# {'select': {'value': 'building'}, 'from': 'Faculty', 'groupby': {'value': 'building'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# ['n:Faculty']
# {'select': {'value': 'building'}, 'from': 'Faculty', 'groupby': {'value': 'building'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# ['n:Faculty']
# {'select': [{'value': 'building'}, {'value': {'count': '*'}}], 'from': 'Faculty', 'groupby': {'value': 'building'}}
# ['n:Faculty']
# {'select': [{'value': 'building'}, {'value': {'count': '*'}}], 'from': 'Faculty', 'groupby': {'value': 'building'}}
# ['n:Faculty']
# {'select': [{'value': 'fname'}, {'value': 'lname'}], 'from': 'Faculty', 'where': {'eq': ['Rank', 'Instructor']}}
# ['n:Faculty']
# {'select': [{'value': 'fname'}, {'value': 'lname'}], 'from': 'Faculty', 'where': {'eq': ['Rank', 'Instructor']}}
# ['n:Faculty']
# {'select': {'value': {'count': '*'}}, 'from': 'Faculty', 'where': {'and': [{'eq': ['Rank', 'Professor']}, {'eq': ['building', 'NEB']}]}}
# ['n:Faculty']
# {'select': {'value': {'count': '*'}}, 'from': 'Faculty', 'where': {'and': [{'eq': ['Rank', 'Professor']}, {'eq': ['building', 'NEB']}]}}
# ['n:Faculty']
# {'select': [{'value': 'phone'}, {'value': 'room'}, {'value': 'building'}], 'from': 'Faculty', 'where': {'and': [{'eq': ['Fname', 'Jerry']}, {'eq': ['Lname', 'Prince']}]}}
# ['n:Faculty']
# {'select': [{'value': 'phone'}, {'value': 'room'}, {'value': 'building'}], 'from': 'Faculty', 'where': {'and': [{'eq': ['Fname', 'Jerry']}, {'eq': ['Lname', 'Prince']}]}}
# ['n:Faculty']
# {'select': [{'value': 'rank'}, {'value': 'sex'}, {'value': {'count': '*'}}], 'from': 'Faculty', 'groupby': [{'value': 'rank'}, {'value': 'sex'}]}
# ['n:Faculty']
# {'select': [{'value': 'faculty.fname'}, {'value': 'faculty.lname'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'groupby': {'value': 'faculty.FacID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'faculty.fname'}, {'value': 'faculty.lname'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Student'}, 'on': {'eq': ['faculty.FacID', 'student.advisor']}}], 'groupby': {'value': 'faculty.FacID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# []
# {'select': [{'value': 'faculty.fname'}, {'value': 'faculty.lname'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}], 'groupby': {'value': 'faculty.FacID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': [{'value': 'faculty.fname'}, {'value': 'faculty.lname'}], 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}], 'groupby': {'value': 'faculty.FacID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': {'distinct': {'value': 'faculty.lname'}}}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}, {'join': {'name': 'T3', 'value': 'activity'}, 'on': {'eq': ['faculty_participates_in.actid', 'faculty_participates_in.actid']}}], 'where': {'or': [{'eq': ['activity.activity_name', {'literal': 'Canoeing'}]}, {'eq': ['activity.activity_name', {'literal': 'Kayaking'}]}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': {'distinct': {'value': 'faculty.lname'}}}, 'from': [{'value': 'Faculty', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['faculty.facID', 'faculty_participates_in.facID']}}, {'join': {'name': 'T3', 'value': 'activity'}, 'on': {'eq': ['faculty_participates_in.actid', 'faculty_participates_in.actid']}}], 'where': {'or': [{'eq': ['activity.activity_name', {'literal': 'Canoeing'}]}, {'eq': ['activity.activity_name', {'literal': 'Kayaking'}]}]}}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': 'activity.activity_name'}, 'from': [{'value': 'Activity', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Participates_in'}, 'on': {'eq': ['activity.actID', 'activity.actID']}}], 'groupby': {'value': 'activity.actID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['student:Student', 'activity:Activity']
# {'select': [{'value': 'student.fname'}, {'value': 'student.lname'}], 'from': [{'value': 'Student', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Participates_in'}, 'on': {'eq': ['student.StuID', 'activity.StuID']}}], 'groupby': {'value': 'student.StuID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['student:Student', 'activity:Activity']
# {'select': [{'value': 'student.fname'}, {'value': 'student.lname'}], 'from': [{'value': 'Student', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Participates_in'}, 'on': {'eq': ['student.StuID', 'activity.StuID']}}], 'groupby': {'value': 'student.StuID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['student:Student', 'activity:Activity']
# {'select': {'value': 'activity.activity_name'}, 'from': [{'value': 'Activity', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['activity.actID', 'faculty_participates_in.actID']}}], 'groupby': {'value': 'activity.actID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': 'activity.activity_name'}, 'from': [{'value': 'Activity', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Faculty_participates_in'}, 'on': {'eq': ['activity.actID', 'faculty_participates_in.actID']}}], 'groupby': {'value': 'activity.actID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['faculty:Faculty', 'activity:Activity']
# {'select': {'value': 'activity.activity_name'}, 'from': [{'value': 'Activity', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Participates_in'}, 'on': {'eq': ['activity.actID', 'activity.actID']}}], 'groupby': {'value': 'activity.actID'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'activity_1', 'db_relationships': [{'Student': {'to': 'Activity', 'relation': 'participates_in', 'mapping': 'Participates_in'}}, {'Faculty': {'to': 'Activity', 'relation': 'faculty_participates_in', 'mapping': 'Faculty_Participates_in'}}]}
# ['student:Student', 'activity:Activity']
# {'select': [{'value': 'aircraft.Aircraft'}, {'value': {'count': '*'}}], 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'MATCH'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'match.Winning_Aircraft']}}], 'groupby': {'value': 'match.Winning_Aircraft'}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'match:match']
# {'select': {'value': 'Name'}, 'from': 'pilot', 'orderby': {'value': 'Age', 'sort': 'desc'}}
# ['n:pilot']
# {'select': [{'value': 'aircraft.Aircraft'}, {'value': {'count': '*'}}], 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'MATCH'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'match.Winning_Aircraft']}}], 'groupby': {'value': 'match.Winning_Aircraft'}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'match:match']
# {'select': [{'value': 'match.Location'}, {'value': 'aircraft.Aircraft'}], 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'MATCH'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'match.Winning_Aircraft']}}]}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'match:match']
# {'select': {'value': 'aircraft.Aircraft'}, 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'MATCH'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'match.Winning_Aircraft']}}], 'groupby': {'value': 'match.Winning_Aircraft'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'match:match']
# {'select': [{'value': 'match.Location'}, {'value': 'aircraft.Aircraft'}], 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'MATCH'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'match.Winning_Aircraft']}}]}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'match:match']
# {'select': {'value': 'Name'}, 'from': 'pilot', 'orderby': {'value': 'Age', 'sort': 'desc'}}
# ['n:pilot']
# {'select': {'value': 'aircraft.Aircraft'}, 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'MATCH'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'match.Winning_Aircraft']}}], 'groupby': {'value': 'match.Winning_Aircraft'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'match:match']
# {'select': {'value': 'aircraft.Aircraft'}, 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'MATCH'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'match.Winning_Aircraft']}}], 'groupby': {'value': 'match.Winning_Aircraft'}, 'having': {'gte': [{'count': '*'}, 2]}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'match:match']
# {'select': [{'value': 'pilot.name'}, {'value': 'pilot.age'}], 'from': [{'value': 'pilot', 'name': 't1'}, {'join': {'name': 't2', 'value': 'MATCH'}, 'on': {'eq': ['pilot.pilot_id', 'match.winning_pilot']}}], 'orderby': {'value': 'pilot.age'}, 'limit': 1}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['pilot:pilot', 'match:match']
# {'select': {'value': 'Aircraft'}, 'from': 'aircraft', 'where': {'nin': ['Aircraft_ID', {'select': {'value': 'Winning_Aircraft'}, 'from': 'MATCH'}]}}
# {'select': {'value': 'Aircraft'}, 'from': 'aircraft', 'where': {'nin': ['Aircraft_ID', {'select': {'value': 'Winning_Aircraft'}, 'from': 'MATCH'}]}}
# {'select': '*', 'from': 'airport', 'orderby': {'value': 'International_Passengers', 'sort': 'desc'}, 'limit': 1}
# ['n:airport']
# {'select': '*', 'from': 'airport', 'orderby': {'value': 'International_Passengers', 'sort': 'desc'}, 'limit': 1}
# ['n:airport']
# {'select': [{'value': 'pilot.name'}, {'value': 'pilot.age'}], 'from': [{'value': 'pilot', 'name': 't1'}, {'join': {'name': 't2', 'value': 'MATCH'}, 'on': {'eq': ['pilot.pilot_id', 'match.winning_pilot']}}], 'where': {'lt': ['pilot.age', 30]}, 'groupby': {'value': 'match.winning_pilot'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['pilot:pilot', 'match:match']
# {'select': [{'value': 'pilot.name'}, {'value': 'pilot.age'}], 'from': [{'value': 'pilot', 'name': 't1'}, {'join': {'name': 't2', 'value': 'MATCH'}, 'on': {'eq': ['pilot.pilot_id', 'match.winning_pilot']}}], 'where': {'lt': ['pilot.age', 30]}, 'groupby': {'value': 'match.winning_pilot'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['pilot:pilot', 'match:match']
# {'select': {'value': {'avg': 'airport.Total_Passengers'}}, 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'airport_aircraft'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'airport.Aircraft_ID']}}, {'join': {'name': 'T3', 'value': 'airport'}, 'on': {'eq': ['airport.Airport_ID', 'airport.Airport_ID']}}], 'where': {'eq': ['aircraft.Aircraft', 'Robinson R-22']}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'airport:airport']
# {'select': [{'value': 'pilot.name'}, {'value': 'pilot.age'}], 'from': [{'value': 'pilot', 'name': 't1'}, {'join': {'name': 't2', 'value': 'MATCH'}, 'on': {'eq': ['pilot.pilot_id', 'match.winning_pilot']}}], 'orderby': {'value': 'pilot.age'}, 'limit': 1}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['pilot:pilot', 'match:match']
# {'select': {'value': 'aircraft.Aircraft'}, 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'MATCH'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'match.Winning_Aircraft']}}], 'groupby': {'value': 'match.Winning_Aircraft'}, 'having': {'gte': [{'count': '*'}, 2]}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'match:match']
# {'select': {'value': {'avg': 'airport.Total_Passengers'}}, 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'airport_aircraft'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'airport.Aircraft_ID']}}, {'join': {'name': 'T3', 'value': 'airport'}, 'on': {'eq': ['airport.Airport_ID', 'airport.Airport_ID']}}], 'where': {'eq': ['aircraft.Aircraft', 'Robinson R-22']}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'airport:airport']
# {'select': {'value': 'Name'}, 'from': 'pilot', 'where': {'gte': ['Age', 25]}}
# ['n:pilot']
# {'select': [{'value': 'aircraft.Aircraft'}, {'value': 'aircraft.Description'}], 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'airport_aircraft'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'airport.Aircraft_ID']}}, {'join': {'name': 'T3', 'value': 'airport'}, 'on': {'eq': ['airport.Airport_ID', 'airport.Airport_ID']}}], 'where': {'gt': ['airport.Total_Passengers', 10000000]}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'airport:airport']
# {'select': {'value': 'name'}, 'from': 'pilot', 'where': {'nin': ['pilot_id', {'select': {'value': 'Winning_Pilot'}, 'from': 'MATCH', 'where': {'eq': ['country', {'literal': 'Australia'}]}}]}}
# {'select': {'value': {'count': '*'}}, 'from': 'aircraft'}
# ['n:aircraft']
# {'select': {'value': {'count': '*'}}, 'from': 'aircraft'}
# ['n:aircraft']
# {'select': {'value': 'Description'}, 'from': 'aircraft'}
# ['n:aircraft']
# {'select': {'value': 'Description'}, 'from': 'aircraft'}
# ['n:aircraft']
# {'select': {'value': {'avg': 'International_Passengers'}}, 'from': 'airport'}
# ['n:airport']
# {'select': {'value': {'avg': 'International_Passengers'}}, 'from': 'airport'}
# ['n:airport']
# {'select': [{'value': 'International_Passengers'}, {'value': 'Domestic_Passengers'}], 'from': 'airport', 'where': {'eq': ['Airport_Name', 'London Heathrow']}}
# ['n:airport']
# {'select': [{'value': 'International_Passengers'}, {'value': 'Domestic_Passengers'}], 'from': 'airport', 'where': {'eq': ['Airport_Name', 'London Heathrow']}}
# ['n:airport']
# {'select': [{'value': 'aircraft.Aircraft'}, {'value': 'aircraft.Description'}], 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'airport_aircraft'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'airport.Aircraft_ID']}}, {'join': {'name': 'T3', 'value': 'airport'}, 'on': {'eq': ['airport.Airport_ID', 'airport.Airport_ID']}}], 'where': {'gt': ['airport.Total_Passengers', 10000000]}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'airport:airport']
# {'select': {'value': {'sum': 'Domestic_Passengers'}}, 'from': 'airport', 'where': {'like': ['Airport_Name', '%London%']}}
# {'select': [{'value': {'max': 'Transit_Passengers'}}, {'value': {'min': 'Transit_Passengers'}}], 'from': 'airport'}
# ['n:airport']
# {'select': [{'value': {'max': 'Transit_Passengers'}}, {'value': {'min': 'Transit_Passengers'}}], 'from': 'airport'}
# ['n:airport']
# {'select': {'value': 'Name'}, 'from': 'pilot', 'where': {'gte': ['Age', 25]}}
# ['n:pilot']
# {'select': {'value': 'Name'}, 'from': 'pilot', 'orderby': {'value': 'Name', 'sort': 'asc'}}
# ['n:pilot']
# {'select': {'value': 'Name'}, 'from': 'pilot', 'orderby': {'value': 'Name', 'sort': 'asc'}}
# ['n:pilot']
# {'select': {'value': 'Name'}, 'from': 'pilot', 'where': {'lte': ['Age', 30]}, 'orderby': {'value': 'Name', 'sort': 'desc'}}
# ['n:pilot']
# {'select': {'value': 'Name'}, 'from': 'pilot', 'where': {'lte': ['Age', 30]}, 'orderby': {'value': 'Name', 'sort': 'desc'}}
# ['n:pilot']
# {'select': {'value': 'aircraft.Aircraft'}, 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'airport_aircraft'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'airport.Aircraft_ID']}}, {'join': {'name': 'T3', 'value': 'airport'}, 'on': {'eq': ['airport.Airport_ID', 'airport.Airport_ID']}}], 'where': {'eq': ['airport.Airport_Name', 'London Gatwick']}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'airport:airport']
# {'select': {'value': 'aircraft.Aircraft'}, 'from': [{'value': 'aircraft', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'airport_aircraft'}, 'on': {'eq': ['aircraft.Aircraft_ID', 'airport.Aircraft_ID']}}, {'join': {'name': 'T3', 'value': 'airport'}, 'on': {'eq': ['airport.Airport_ID', 'airport.Airport_ID']}}], 'where': {'eq': ['airport.Airport_Name', 'London Gatwick']}}
# {'db_id': 'aircraft', 'db_relationships': [{'pilot': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'match', 'relation': 'wins'}}, {'aircraft': {'to': 'airport', 'relation': 'associtated_with', 'mapping': 'airport_aircraft'}}]}
# ['aircraft:aircraft', 'airport:airport']
# {'select': {'value': {'sum': 'Domestic_Passengers'}}, 'from': 'airport', 'where': {'like': ['Airport_Name', '%London%']}}
# {'select': {'value': 'name'}, 'from': 'pilot', 'where': {'nin': ['pilot_id', {'select': {'value': 'Winning_Pilot'}, 'from': 'MATCH', 'where': {'eq': ['country', {'literal': 'Australia'}]}}]}}
# {'select': {'value': {'count': '*'}}, 'from': 'Student', 'where': {'or': [{'eq': ['city_code', 'HKG']}, {'eq': ['city_code', 'CHI']}]}}
# ['n:Student']
# {'select': {'value': 'Advisor'}, 'from': 'Student', 'where': {'eq': ['StuID', 1004]}}
# ['n:Student']
# {'select': {'value': 'Advisor'}, 'from': 'Student', 'where': {'eq': ['StuID', 1004]}}
# ['n:Student']
# {'select': {'value': 'allergytype'}, 'from': 'Allergy_type', 'groupby': {'value': 'allergytype'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# ['n:Allergy_Type']
# {'select': {'value': 'allergytype'}, 'from': 'Allergy_type', 'groupby': {'value': 'allergytype'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# ['n:Allergy_Type']
# {'select': [{'value': 'allergytype'}, {'value': {'count': '*'}}], 'from': 'Allergy_type', 'groupby': {'value': 'allergytype'}}
# ['n:Allergy_Type']
# {'select': [{'value': 'allergytype'}, {'value': {'count': '*'}}], 'from': 'Allergy_type', 'groupby': {'value': 'allergytype'}}
# ['n:Allergy_Type']
# {'select': {'value': {'count': '*'}}, 'from': 'Allergy_type', 'where': {'eq': ['allergytype', 'animal']}}
# ['n:Allergy_Type']
# {'select': {'value': {'count': '*'}}, 'from': 'Allergy_type', 'where': {'eq': ['allergytype', 'animal']}}
# ['n:Allergy_Type']
# {'select': {'value': 'allergytype'}, 'from': 'Allergy_type', 'where': {'eq': ['allergy', 'Cat']}}
# ['n:Allergy_Type']
# {'select': {'value': 'allergytype'}, 'from': 'Allergy_type', 'where': {'eq': ['allergy', 'Cat']}}
# ['n:Allergy_Type']
# {'select': {'value': {'distinct': {'value': 'allergy'}}}, 'from': 'Allergy_type', 'where': {'eq': ['allergytype', 'food']}}
# ['n:Allergy_Type']
# {'select': {'value': {'distinct': {'value': 'allergy'}}}, 'from': 'Allergy_type', 'where': {'eq': ['allergytype', 'food']}}
# ['n:Allergy_Type']
# {'select': [{'value': 'allergy'}, {'value': 'allergytype'}], 'from': 'Allergy_type'}
# ['n:Allergy_Type']
# {'select': [{'value': 'allergy'}, {'value': 'allergytype'}], 'from': 'Allergy_type'}
# ['n:Allergy_Type']
# {'select': {'value': {'distinct': {'value': 'allergytype'}}}, 'from': 'Allergy_type'}
# ['n:Allergy_Type']
# {'select': {'value': {'distinct': {'value': 'allergytype'}}}, 'from': 'Allergy_type'}
# ['n:Allergy_Type']
# {'select': {'value': {'count': {'distinct': {'value': 'allergytype'}}}}, 'from': 'Allergy_type'}
# ['n:Allergy_Type']
# {'select': {'value': {'count': {'distinct': {'value': 'allergytype'}}}}, 'from': 'Allergy_type'}
# ['n:Allergy_Type']
# {'select': {'value': {'count': {'distinct': {'value': 'allergy'}}}}, 'from': 'Allergy_type'}
# ['n:Allergy_Type']
# {'select': {'value': 'allergytype'}, 'from': 'Allergy_type', 'groupby': {'value': 'allergytype'}, 'orderby': {'value': {'count': '*'}, 'sort': 'asc'}, 'limit': 1}
# ['n:Allergy_Type']
# {'select': {'value': 'allergytype'}, 'from': 'Allergy_type', 'groupby': {'value': 'allergytype'}, 'orderby': {'value': {'count': '*'}, 'sort': 'asc'}, 'limit': 1}
# ['n:Allergy_Type']
# {'select': {'value': {'count': '*'}}, 'from': 'Student'}
# ['n:Student']
# {'select': {'value': {'count': '*'}}, 'from': 'Student'}
# ['n:Student']
# {'select': {'value': 'city_code'}, 'from': 'Student', 'where': {'eq': ['LName', 'Kim']}}
# ['n:Student']
# {'select': {'value': 'city_code'}, 'from': 'Student', 'where': {'eq': ['LName', 'Kim']}}
# ['n:Student']
# {'select': {'value': 'StuID'}, 'from': 'Student', 'where': {'gt': ['age', 20]}}
# ['n:Student']
# {'select': {'value': 'StuID'}, 'from': 'Student', 'where': {'gt': ['age', 20]}}
# ['n:Student']
# {'select': {'value': {'count': '*'}}, 'from': 'Student', 'where': {'eq': ['age', 18]}}
# ['n:Student']
# {'select': {'value': {'count': '*'}}, 'from': 'Student', 'where': {'eq': ['age', 18]}}
# ['n:Student']
# {'select': {'value': 'StuID'}, 'from': 'Student', 'where': {'eq': ['Sex', {'literal': 'M'}]}}
# ['n:Student']
# {'select': {'value': 'StuID'}, 'from': 'Student', 'where': {'eq': ['Sex', {'literal': 'M'}]}}
# ['n:Student']
# {'select': {'value': {'count': '*'}}, 'from': 'Student', 'where': {'or': [{'eq': ['city_code', 'HKG']}, {'eq': ['city_code', 'CHI']}]}}
# ['n:Student']
# {'select': [{'value': 'Fname'}, {'value': 'Lname'}, {'value': 'Age'}], 'from': 'Student', 'where': {'eq': ['Sex', {'literal': 'F'}]}}
# ['n:Student']
# {'select': {'value': {'distinct': {'value': 'city_code'}}}, 'from': 'Student'}
# ['n:Student']
# {'select': {'value': {'distinct': {'value': 'city_code'}}}, 'from': 'Student'}
# ['n:Student']
# {'select': {'value': {'distinct': {'value': 'Major'}}}, 'from': 'Student'}
# ['n:Student']
# {'select': {'value': {'distinct': {'value': 'Major'}}}, 'from': 'Student'}
# ['n:Student']
# {'select': {'value': {'count': {'distinct': {'value': 'advisor'}}}}, 'from': 'Student'}
# ['n:Student']
# {'select': {'value': {'count': {'distinct': {'value': 'advisor'}}}}, 'from': 'Student'}
# ['n:Student']
# {'select': [{'value': 'Fname'}, {'value': 'Lname'}], 'from': 'Student'}
# ['n:Student']
# {'select': [{'value': 'Fname'}, {'value': 'Lname'}], 'from': 'Student'}
# ['n:Student']
# {'select': [{'value': 'Fname'}, {'value': 'Lname'}, {'value': 'Age'}], 'from': 'Student', 'where': {'eq': ['Sex', {'literal': 'F'}]}}
# ['n:Student']
# {'select': [{'value': {'min': 'age'}}, {'value': {'avg': 'age'}}, {'value': {'max': 'age'}}], 'from': 'Student'}
# ['n:Student']
# {'select': {'value': 'StuID'}, 'from': 'Has_allergy', 'groupby': {'value': 'StuID'}, 'having': {'gte': [{'count': '*'}, 2]}}
# ['n:Has_Allergy']
# {'select': {'value': 'LName'}, 'from': 'Student', 'where': {'eq': ['age', {'select': {'value': {'min': 'age'}}, 'from': 'Student'}]}}
# {'select': {'value': 'Allergy'}, 'from': 'Has_allergy', 'groupby': {'value': 'Allergy'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# ['n:Has_Allergy']
# {'select': [{'value': 'Allergy'}, {'value': {'count': '*'}}], 'from': 'Has_allergy', 'groupby': {'value': 'Allergy'}}
# ['n:Has_Allergy']
# {'select': [{'value': 'Allergy'}, {'value': {'count': '*'}}], 'from': 'Has_allergy', 'groupby': {'value': 'Allergy'}}
# ['n:Has_Allergy']
# {'select': [{'value': 'allergy_type.allergytype'}, {'value': {'count': '*'}}], 'from': [{'value': 'Has_allergy', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Allergy_type'}, 'on': {'eq': ['has_allergy.allergy', 'allergy_type.allergy']}}], 'groupby': {'value': 'allergy_type.allergytype'}}
# {'db_id': 'allergy_1', 'db_relationships': [{'Student': {'to': 'Allergy_Type', 'relation': 'allergic_to', 'mapping': 'Has_Allergy'}}]}
# ['student:Student', 'allergy_type:Allergy_Type']
# {'select': [{'value': 'allergy_type.allergytype'}, {'value': {'count': '*'}}], 'from': [{'value': 'Has_allergy', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Allergy_type'}, 'on': {'eq': ['has_allergy.allergy', 'allergy_type.allergy']}}], 'groupby': {'value': 'allergy_type.allergytype'}}
# {'db_id': 'allergy_1', 'db_relationships': [{'Student': {'to': 'Allergy_Type', 'relation': 'allergic_to', 'mapping': 'Has_Allergy'}}]}
# ['student:Student', 'allergy_type:Allergy_Type']
# {'select': [{'value': 'allergy_type.Allergy'}, {'value': 'allergy_type.AllergyType'}], 'from': [{'value': 'Allergy_type', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Has_allergy'}, 'on': {'eq': ['allergy_type.Allergy', 'has_allergy.Allergy']}}, {'join': {'name': 'T3', 'value': 'Student'}, 'on': {'eq': ['student.StuID', 'has_allergy.StuID']}}], 'where': {'eq': ['student.Fname', 'Lisa']}, 'orderby': {'value': 'allergy_type.Allergy'}}
# {'db_id': 'allergy_1', 'db_relationships': [{'Student': {'to': 'Allergy_Type', 'relation': 'allergic_to', 'mapping': 'Has_Allergy'}}]}
# ['student:Student', 'allergy_type:Allergy_Type']
# {'select': [{'value': 'allergy_type.Allergy'}, {'value': 'allergy_type.AllergyType'}], 'from': [{'value': 'Allergy_type', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Has_allergy'}, 'on': {'eq': ['allergy_type.Allergy', 'has_allergy.Allergy']}}, {'join': {'name': 'T3', 'value': 'Student'}, 'on': {'eq': ['student.StuID', 'has_allergy.StuID']}}], 'where': {'eq': ['student.Fname', 'Lisa']}, 'orderby': {'value': 'allergy_type.Allergy'}}
# {'db_id': 'allergy_1', 'db_relationships': [{'Student': {'to': 'Allergy_Type', 'relation': 'allergic_to', 'mapping': 'Has_Allergy'}}]}
# ['student:Student', 'allergy_type:Allergy_Type']
# {'select': {'value': {'distinct': [{'value': 'student.fname'}, {'value': 'student.city_code'}]}}, 'from': [{'value': 'Student', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Has_Allergy'}, 'on': {'eq': ['student.stuid', 'allergy_type.stuid']}}], 'where': {'or': [{'eq': ['allergy_type.Allergy', 'Milk']}, {'eq': ['allergy_type.Allergy', 'Cat']}]}}
# {'db_id': 'allergy_1', 'db_relationships': [{'Student': {'to': 'Allergy_Type', 'relation': 'allergic_to', 'mapping': 'Has_Allergy'}}]}
# ['student:Student', 'allergy_type:Allergy_Type']
# {'select': {'value': {'distinct': [{'value': 'student.fname'}, {'value': 'student.city_code'}]}}, 'from': [{'value': 'Student', 'name': 'T1'}, {'join': {'name': 'T2', 'value': 'Has_Allergy'}, 'on': {'eq': ['student.stuid', 'allergy_type.stuid']}}], 'where': {'or': [{'eq': ['allergy_type.Allergy', 'Milk']}, {'eq': ['allergy_type.Allergy', 'Cat']}]}}
# {'db_id': 'allergy_1', 'db_relationships': [{'Student': {'to': 'Allergy_Type', 'relation': 'allergic_to', 'mapping': 'Has_Allergy'}}]}
# ['student:Student', 'allergy_type:Allergy_Type']
# {'select': [{'value': 'fname'}, {'value': 'major'}], 'from': 'Student', 'where': {'nin': ['StuID', {'select': {'value': 'StuID'}, 'from': 'Has_allergy', 'where': {'eq': ['Allergy', 'Soy']}}]}}
# {'select': [{'value': 'fname'}, {'value': 'major'}], 'from': 'Student', 'where': {'nin': ['StuID', {'select': {'value': 'StuID'}, 'from': 'Has_allergy', 'where': {'eq': ['Allergy', 'Soy']}}]}}
# {'select': [{'value': {'min': 'age'}}, {'value': {'avg': 'age'}}, {'value': {'max': 'age'}}], 'from': 'Student'}
# ['n:Student']
# {'select': {'value': 'Allergy'}, 'from': 'Has_allergy', 'groupby': {'value': 'Allergy'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# ['n:Has_Allergy']
# ...
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# {'select': {'value': 'catalog_contents.catalog_entry_name'}, 'from': [{'value': 'Catalog_Contents', 'name': 't1'}, {'join': {'name': 't2', 'value': 'Catalog_Contents_Additional_Attributes'}, 'on': {'eq': ['catalog_contents.catalog_entry_id', 'catalog_contents_additional_attributes.catalog_entry_id']}}], 'where': {'eq': ['catalog_contents_additional_attributes.attribute_value', {'select': {'value': 'attribute_value'}, 'from': 'Catalog_Contents_Additional_Attributes', 'groupby': {'value': 'attribute_value'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}]}}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# {'select': [{'value': 'catalogs.catalog_name'}, {'value': 'catalogs.date_of_publication'}], 'from': [{'value': 'catalogs', 'name': 't1'}, {'join': {'name': 't2', 'value': 'catalog_structure'}, 'on': {'eq': ['catalogs.catalog_id', 'catalog_structure.catalog_id']}}], 'where': {'gt': ['catalog_level_number', 5]}}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# ['catalog_structure:Catalog_Structure', 'catalogs:Catalogs']
# {'select': [{'value': 'catalogs.catalog_name'}, {'value': 'catalogs.date_of_publication'}], 'from': [{'value': 'catalogs', 'name': 't1'}, {'join': {'name': 't2', 'value': 'catalog_structure'}, 'on': {'eq': ['catalogs.catalog_id', 'catalog_structure.catalog_id']}}], 'where': {'gt': ['catalog_level_number', 5]}}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# ['catalog_structure:Catalog_Structure', 'catalogs:Catalogs']
# {'select': {'value': 'catalog_publisher'}, 'from': 'catalogs', 'groupby': {'value': 'catalog_publisher'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# ['n:Catalogs']
# {'select': {'value': 'catalog_structure.catalog_level_name'}, 'from': [{'value': 'catalog_contents', 'name': 't1'}, {'join': {'name': 't2', 'value': 'catalog_structure'}, 'on': {'eq': ['catalog_contents.catalog_level_number', 'catalog_structure.catalog_level_number']}}], 'orderby': {'value': 'catalog_contents.price_in_dollars'}, 'limit': 1}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# ['catalog_contents:Catalog_Contents', 'catalog_structure:Catalog_Structure']
# {'select': {'value': 'catalog_publisher'}, 'from': 'catalogs', 'groupby': {'value': 'catalog_publisher'}, 'orderby': {'value': {'count': '*'}, 'sort': 'desc'}, 'limit': 1}
# ['n:Catalogs']
# {'select': {'value': {'distinct': {'value': 'catalog_publisher'}}}, 'from': 'catalogs', 'where': {'like': ['catalog_publisher', '%Murray%']}}
# {'select': [{'value': 'catalog_level_name'}, {'value': 'catalog_level_number'}], 'from': 'Catalog_Structure', 'where': {'between': ['catalog_level_number', 5, 10]}}
# {'select': [{'value': 'catalog_level_name'}, {'value': 'catalog_level_number'}], 'from': 'Catalog_Structure', 'where': {'between': ['catalog_level_number', 5, 10]}}
# {'select': {'value': 'attribute_data_type'}, 'from': 'Attribute_Definitions', 'where': {'eq': ['attribute_name', 'Green']}}
# ['n:Attribute_Definitions']
# {'select': {'value': 'attribute_data_type'}, 'from': 'Attribute_Definitions', 'where': {'eq': ['attribute_name', 'Green']}}
# ['n:Attribute_Definitions']
# {'select': {'value': 'attribute_data_type'}, 'from': 'Attribute_Definitions', 'groupby': {'value': 'attribute_data_type'}, 'having': {'gt': [{'count': '*'}, 3]}}
# ['n:Attribute_Definitions']
# {'select': {'value': 'attribute_data_type'}, 'from': 'Attribute_Definitions', 'groupby': {'value': 'attribute_data_type'}, 'having': {'gt': [{'count': '*'}, 3]}}
# ['n:Attribute_Definitions']
# {'select': {'value': {'distinct': {'value': 'catalog_publisher'}}}, 'from': 'catalogs', 'where': {'like': ['catalog_publisher', '%Murray%']}}
# {'select': {'value': 'catalog_structure.catalog_level_name'}, 'from': [{'value': 'catalog_contents', 'name': 't1'}, {'join': {'name': 't2', 'value': 'catalog_structure'}, 'on': {'eq': ['catalog_contents.catalog_level_number', 'catalog_structure.catalog_level_number']}}], 'orderby': {'value': 'catalog_contents.price_in_dollars'}, 'limit': 1}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# ['catalog_contents:Catalog_Contents', 'catalog_structure:Catalog_Structure']
# {'select': [{'value': {'avg': 'price_in_euros'}}, {'value': {'min': 'price_in_euros'}}], 'from': 'catalog_contents'}
# ['n:Catalog_Contents']
# {'select': [{'value': {'avg': 'price_in_euros'}}, {'value': {'min': 'price_in_euros'}}], 'from': 'catalog_contents'}
# ['n:Catalog_Contents']
# {'select': {'value': {'count': '*'}}, 'from': 'catalog_contents'}
# ['n:Catalog_Contents']
# {'select': {'value': {'count': '*'}}, 'from': 'catalog_contents'}
# ['n:Catalog_Contents']
# {'select': {'value': 'date_of_latest_revision'}, 'from': 'Catalogs', 'groupby': {'value': 'date_of_latest_revision'}, 'having': {'gt': [{'count': '*'}, 1]}}
# ['n:Catalogs']
# {'select': {'value': 'date_of_latest_revision'}, 'from': 'Catalogs', 'groupby': {'value': 'date_of_latest_revision'}, 'having': {'gt': [{'count': '*'}, 1]}}
# ['n:Catalogs']
# {'select': [{'value': 'catalog_entry_name'}, {'value': 'capacity'}], 'from': 'Catalog_Contents', 'where': {'gt': ['price_in_dollars', 700]}}
# ['n:Catalog_Contents']
# {'select': [{'value': 'catalog_entry_name'}, {'value': 'capacity'}], 'from': 'Catalog_Contents', 'where': {'gt': ['price_in_dollars', 700]}}
# ['n:Catalog_Contents']
# {'select': [{'value': 'attribute_definitions.attribute_name'}, {'value': 'attribute_definitions.attribute_id'}], 'from': [{'value': 'Attribute_Definitions', 'name': 't1'}, {'join': {'name': 't2', 'value': 'Catalog_Contents_Additional_Attributes'}, 'on': {'eq': ['attribute_definitions.attribute_id', 'catalog_contents_additional_attributes.attribute_id']}}], 'where': {'eq': ['catalog_contents_additional_attributes.attribute_value', 0]}}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# []
# {'select': [{'value': 'attribute_definitions.attribute_name'}, {'value': 'attribute_definitions.attribute_id'}], 'from': [{'value': 'Attribute_Definitions', 'name': 't1'}, {'join': {'name': 't2', 'value': 'Catalog_Contents_Additional_Attributes'}, 'on': {'eq': ['attribute_definitions.attribute_id', 'catalog_contents_additional_attributes.attribute_id']}}], 'where': {'eq': ['catalog_contents_additional_attributes.attribute_value', 0]}}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# []
# {'select': {'value': 'catalog_entry_name'}, 'from': 'catalog_contents', 'where': {'or': [{'lt': ['LENGTH', 3]}, {'gt': ['width', 5]}]}}
# ['n:Catalog_Contents']
# {'select': {'value': 'catalog_entry_name'}, 'from': 'catalog_contents', 'where': {'or': [{'lt': ['LENGTH', 3]}, {'gt': ['width', 5]}]}}
# ['n:Catalog_Contents']
# {'select': {'value': 'catalog_contents.catalog_entry_name'}, 'from': [{'value': 'Catalog_Contents', 'name': 't1'}, {'join': {'name': 't2', 'value': 'Catalog_Contents_Additional_Attributes'}, 'on': {'eq': ['catalog_contents.catalog_entry_id', 'catalog_contents_additional_attributes.catalog_entry_id']}}], 'where': {'eq': ['catalog_contents_additional_attributes.catalog_level_number', '8']}}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# ['catalog_contents_additional_attributes:Catalog_Contents_Additional_Attributes', 'catalog_contents:Catalog_Contents']
# {'select': {'value': 'catalog_contents.catalog_entry_name'}, 'from': [{'value': 'Catalog_Contents', 'name': 't1'}, {'join': {'name': 't2', 'value': 'Catalog_Contents_Additional_Attributes'}, 'on': {'eq': ['catalog_contents.catalog_entry_id', 'catalog_contents_additional_attributes.catalog_entry_id']}}], 'where': {'eq': ['catalog_contents_additional_attributes.catalog_level_number', '8']}}
# {'db_id': 'product_catalog', 'db_relationships': [{'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}, {'Catalog_Contents_Additional_Attributes': {'to': 'Catalog_Contents', 'relation': 'belongs_to'}}, {'Catalog_Structure': {'to': 'Catalogs', 'relation': 'belongs_to'}}, {'Catalog_Contents': {'to': 'Catalog_Structure', 'relation': 'belongs_to'}}]}
# ['catalog_contents_additional_attributes:Catalog_Contents_Additional_Attributes', 'catalog_contents:Catalog_Contents']
# {'select': {'value': 'catalog_entry_name'}, 'from': 'catalog_contents', 'where': {'like': ['product_stock_number', '2%']}}
# {'select': {'value': 'catalog_entry_name'}, 'from': 'catalog_contents', 'orderby': {'value': 'capacity', 'sort': 'asc'}, 'limit': 1}
# ['n:Catalog_Contents']
# {'select': {'value': 'catalog_entry_name'}, 'from': 'catalog_contents', 'orderby': {'value': 'capacity', 'sort': 'asc'}, 'limit': 1}
# ['n:Catalog_Contents']
# {'select': {'value': 'catalog_entry_name'}, 'from': 'catalog_contents', 'orderby': {'value': 'height', 'sort': 'desc'}, 'limit': 1}
# ['n:Catalog_Contents']
# {'select': {'value': 'catalog_entry_name'}, 'from': 'catalog_contents', 'orderby': {'value': 'height', 'sort': 'desc'}, 'limit': 1}
# ['n:Catalog_Contents']
# {'select': {'value': {'distinct': {'value': 'catalog_entry_name'}}}, 'from': 'catalog_contents'}
# ['n:Catalog_Contents']
# {'select': {'value': 'catalog_entry_name'}, 'from': 'catalog_contents', 'where': {'like': ['product_stock_number', '2%']}}
#                 db_id                                              query  \
# 0          activity_1  SELECT T1.activity_name ,  count(*) FROM Activ...
# 1          activity_1  SELECT Fname ,  Lname ,  phone FROM Faculty WH...
# 2          activity_1  SELECT Fname ,  Lname ,  phone FROM Faculty WH...
# 3          activity_1         SELECT rank ,  Fname ,  Lname FROM Faculty
# 4          activity_1         SELECT rank ,  Fname ,  Lname FROM Faculty
# ...               ...                                                ...
# 5043  product_catalog  SELECT catalog_entry_name FROM catalog_content...
# 5044  product_catalog  SELECT catalog_entry_name FROM catalog_content...
# 5045  product_catalog  SELECT catalog_entry_name FROM catalog_content...
# 5046  product_catalog  SELECT distinct(catalog_entry_name) FROM catal...
# 5047  product_catalog  SELECT catalog_entry_name FROM catalog_content...
#
#                                              query_toks  \
# 0     [SELECT, T1.activity_name, ,, count, (, *, ), ...
# 1     [SELECT, Fname, ,, Lname, ,, phone, FROM, Facu...
# 2     [SELECT, Fname, ,, Lname, ,, phone, FROM, Facu...
# 3     [SELECT, rank, ,, Fname, ,, Lname, FROM, Faculty]
# 4     [SELECT, rank, ,, Fname, ,, Lname, FROM, Faculty]
# ...                                                 ...
# 5043  [SELECT, catalog_entry_name, FROM, catalog_con...
# 5044  [SELECT, catalog_entry_name, FROM, catalog_con...
# 5045  [SELECT, catalog_entry_name, FROM, catalog_con...
# 5046  [SELECT, distinct, (, catalog_entry_name, ), F...
# 5047  [SELECT, catalog_entry_name, FROM, catalog_con...
#
#                                     query_toks_no_value  \
# 0     [select, t1, ., activity_name, ,, count, (, *,...
# 1     [select, fname, ,, lname, ,, phone, from, facu...
# 2     [select, fname, ,, lname, ,, phone, from, facu...
# 3     [select, rank, ,, fname, ,, lname, from, faculty]
# 4     [select, rank, ,, fname, ,, lname, from, faculty]
# ...                                                 ...
# 5043  [select, catalog_entry_name, from, catalog_con...
# 5044  [select, catalog_entry_name, from, catalog_con...
# 5045  [select, catalog_entry_name, from, catalog_con...
# 5046  [select, distinct, (, catalog_entry_name, ), f...
# 5047  [select, catalog_entry_name, from, catalog_con...
#
#                                                question  \
# 0     How many faculty members participate in each a...
# 1     What are the first name, last name, and phone ...
# 2     Show the first name, last name, and phone numb...
# 3     What are the rank, first name, and last name o...
# 4     Show the rank, first name, and last name for a...
# ...                                                 ...
# 5043  Find the name of the product that has the smal...
# 5044  Which catalog content has the highest height? ...
# 5045  What is the product with the highest height? G...
# 5046         Find the names of all the catalog entries.
# 5047  Which catalog contents have a product stock nu...
#
#                                           question_toks
# 0     [How, many, faculty, members, participate, in,...
# 1     [What, are, the, first, name, ,, last, name, ,...
# 2     [Show, the, first, name, ,, last, name, ,, and...
# 3     [What, are, the, rank, ,, first, name, ,, and,...
# 4     [Show, the, rank, ,, first, name, ,, and, last...
# ...                                                 ...
# 5043  [Find, the, name, of, the, product, that, has,...
# 5044  [Which, catalog, content, has, the, highest, h...
# 5045  [What, is, the, product, with, the, highest, h...
# 5046  [Find, the, names, of, all, the, catalog, entr...
# 5047  [Which, catalog, contents, have, a, product, s...
#
# [5048 rows x 6 columns]

# %%
spider_graph_df
# Out:
#                 db_id                                              query  \
# 0          activity_1  MATCH  (faculty:Faculty)-[:faculty_participate...
# 1          activity_1  MATCH (n:Faculty)  WHERE  n.Sex = 'F'  RETURN ...
# 2          activity_1  MATCH (n:Faculty)  WHERE  n.Sex = 'F'  RETURN ...
# 3          activity_1  MATCH (n:Faculty)  RETURN n.rank, n.Fname, n.L...
# 4          activity_1  MATCH (n:Faculty)  RETURN n.rank, n.Fname, n.L...
# ...               ...                                                ...
# 5043  product_catalog  MATCH (n:Catalog_Contents)  RETURN  n.catalog_...
# 5044  product_catalog  MATCH (n:Catalog_Contents)  RETURN  n.catalog_...
# 5045  product_catalog  MATCH (n:Catalog_Contents)  RETURN  n.catalog_...
# 5046  product_catalog  MATCH (n:Catalog_Contents)  RETURN  DISTINCT n...
# 5047  product_catalog                Please make sure the operator exist
#
#      query_toks query_toks_no_value  \
# 0
# 1
# 2
# 3
# 4
# ...         ...                 ...
# 5043
# 5044
# 5045
# 5046
# 5047
#
#                                                question  \
# 0     How many faculty members participate in each a...
# 1     What are the first name, last name, and phone ...
# 2     Show the first name, last name, and phone numb...
# 3     What are the rank, first name, and last name o...
# 4     Show the rank, first name, and last name for a...
# ...                                                 ...
# 5043  Find the name of the product that has the smal...
# 5044  Which catalog content has the highest height? ...
# 5045  What is the product with the highest height? G...
# 5046         Find the names of all the catalog entries.
# 5047  Which catalog contents have a product stock nu...
#
#                                           question_toks
# 0     [How, many, faculty, members, participate, in,...
# 1     [What, are, the, first, name, ,, last, name, ,...
# 2     [Show, the, first, name, ,, last, name, ,, and...
# 3     [What, are, the, rank, ,, first, name, ,, and,...
# 4     [Show, the, rank, ,, first, name, ,, and, last...
# ...                                                 ...
# 5043  [Find, the, name, of, the, product, that, has,...
# 5044  [Which, catalog, content, has, the, highest, h...
# 5045  [What, is, the, product, with, the, highest, h...
# 5046  [Find, the, names, of, all, the, catalog, entr...
# 5047  [Which, catalog, contents, have, a, product, s...
#
# [5048 rows x 6 columns]
